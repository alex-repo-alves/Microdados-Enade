# %% [markdown]
# # <font color='blue'>Carregamento microdados Enade 2019</font>

# %%
# Abrindo o arquivo para leitura
microdados_enade_2019 = open("Dados/microdados_enade_2019.txt", "r")

# %%
# Lendo o arquivo
data_enade_2019 = microdados_enade_2019.read()

# %%
rows = data_enade_2019.split('\n')

# %%
full_data = []

# %%
for row in rows:
    split_row = row.split(";")
    full_data.append(split_row)

# %%
import time

inicio = time.time()
print(full_data[0:3])
fim = time.time()

# %%
print(fim - inicio)

# %% [markdown]
# ### Contando as linhas

# %%
count = 0
for row in full_data:
    count += 1

# %%
print(count)

# %% [markdown]
# ### Contando as colunas

# %%
count = 0
for column in full_data[0]:
    count = count + 1

# %%
print(count)

# %% [markdown]
# ## Inportando o dataset com pandas

# %%
# Importando pandas
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
file_name = "Dados/microdados_enade_2019.txt"

# %%
# Criação do DataFrame com os dados do CSV
# low_memory=False para ignorar a limitação de memória
df = pd.read_csv(file_name, encoding='utf-8', sep=";", low_memory=False)

# %%
df.head()
# Out:
#    NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  CO_MODALIDADE  \
# 0    2019       1       10002       10028      5710         3              1
# 1    2019       1       10002       10028      5710         3              1
# 2    2019       1       10002       10028      5710         3              1
# 3    2019       1       10002       10028      5710         3              1
# 4    2019       1       10002       10028      5710         3              1
#
#    CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  QE_I59 QE_I60  QE_I61  \
# 0         5103403           51                5  ...     2.0    5.0     1.0
# 1         5103403           51                5  ...     1.0    4.0     2.0
# 2         5103403           51                5  ...     3.0    4.0     4.0
# 3         5103403           51                5  ...     3.0    5.0     2.0
# 4         5103403           51                5  ...     NaN    NaN     NaN
#
# ...

# %%
df['CO_GRUPO'].value_counts()
# Out:
# 5710    57261
# 23      41131
# 3501    38905
# 21      32325
# 6208    27749
# 36      22946
# 28      22341
# 5902    21444
# 12      21053
# 5806    18519
# 6       17720
# 19      17650
# 17      14806
# 5       14576
# 55      11466
# 6307     8324
# 6008     8029
# 95       5846
# 5814     5503
# 92       5104
# 4003     4782
# 69       3266
# 51       2895
# 27       2560
# 6405     2012
# 90       1823
# 6002     1790
# 91       1415
# 6410      689
# Name: CO_GRUPO, dtype: int64

# %%
cod = [4003, 5710, 5806, 5814, 5902, 6002, 6008, 6208, 6307, 6405]

# %%
engenharias_ufpa = df.query(f'CO_GRUPO in {cod} and CO_IES == 569')

# %%
engenharias_ufpa.head()
# Out:
#        NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 40916    2019     569       10002       10028      5710     12001
# 40917    2019     569       10002       10028      5710     12001
# 40918    2019     569       10002       10028      5710     12001
# 40919    2019     569       10002       10028      5710     12001
# 40920    2019     569       10002       10028      5710     12001
#
#        CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 40916              1         1501402           15                1  ...
# 40917              1         1501402           15                1  ...
# 40918              1         1501402           15                1  ...
# 40919              1         1501402           15                1  ...
# 40920              1         1501402           15                1  ...
#
#        QE_I59 QE_I60  QE_I61  QE_I62  QE_I63  QE_I64  QE_I65  QE_I66  QE_I67  \
# ...

# %%
engenharias_ufpa['CO_GRUPO'].value_counts()
# Out:
# 5806    223
# 5710    188
# 4003    149
# 6307    113
# 5902    108
# 6008     71
# 6208     35
# 6002     28
# 6405     24
# Name: CO_GRUPO, dtype: int64

# %%
engenharias_ufpa
# Out:
#         NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 40916     2019     569       10002       10028      5710     12001
# 40917     2019     569       10002       10028      5710     12001
# 40918     2019     569       10002       10028      5710     12001
# 40919     2019     569       10002       10028      5710     12001
# 40920     2019     569       10002       10028      5710     12001
# ...        ...     ...         ...         ...       ...       ...
# 361015    2019     569       10002       10028      4003   1191240
# 361016    2019     569       10002       10028      4003   1191240
# 361017    2019     569       10002       10028      4003   1191240
# 361018    2019     569       10002       10028      4003   1191240
# 361019    2019     569       10002       10028      4003   1191240
#
#         CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 40916               1         1501402           15                1  ...
# ...

# %%
df
# Out:
#         NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 0         2019       1       10002       10028      5710         3
# 1         2019       1       10002       10028      5710         3
# 2         2019       1       10002       10028      5710         3
# 3         2019       1       10002       10028      5710         3
# 4         2019       1       10002       10028      5710         3
# ...        ...     ...         ...         ...       ...       ...
# 433925    2019    3948       10008       10022        95   5001378
# 433926    2019    3948       10008       10022        95   5001378
# 433927    2019    3948       10008       10022        95   5001378
# 433928    2019    3948       10008       10022        95   5001378
# 433929    2019    3948       10008       10022        95   5001378
#
#         CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 0                   1         5103403           51                5  ...
# ...

# %%
engenharias_ufpa['CO_UF_CURSO'].value_counts()
# Out:
# 15    939
# Name: CO_UF_CURSO, dtype: int64

# %%
# Importando sweetviz
import sweetviz as sv
import numpy as np

# %%
# Cria o report e chama de my_report
# my_report = sv.analyze(df)

# %%
# Exporta report para HTML
# my_report.show_html()

# %%
engenharias_ufpa = engenharias_ufpa.drop(columns=['NU_ANO', 'CO_IES', 'CO_CATEGAD', 'CO_ORGACAD', 'CO_CURSO', 'CO_MODALIDADE',
                                                 'CO_UF_CURSO', 'CO_REGIAO_CURSO', 'TP_INSCRICAO_ADM', 'TP_INSCRICAO', 
                                                  'NU_ITEM_OFG', 'NU_ITEM_OFG_Z', 'NU_ITEM_OFG_X', 'NU_ITEM_OFG_N', 
                                                  'NU_ITEM_OCE', 'NU_ITEM_OCE_Z', 'NU_ITEM_OCE_X', 'NU_ITEM_OCE_N', 
                                                  'DS_VT_GAB_OFG_ORIG', 'DS_VT_GAB_OFG_FIN', 'TP_PRES'])

# %%
my_report = sv.analyze(engenharias_ufpa)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
eng_ufpa_sem_na = engenharias_ufpa.dropna()

# %%
eng_ufpa_sem_na
# Out:
#         CO_GRUPO  CO_MUNIC_CURSO  NU_IDADE TP_SEXO  ANO_FIM_EM  ANO_IN_GRAD  \
# 40916       5710         1501402        22       M        2014       2015.0
# 40917       5710         1501402        27       F        2009       2014.0
# 40918       5710         1501402        27       F        2009       2011.0
# 40919       5710         1501402        38       M        2009       2014.0
# 40920       5710         1501402        26       M        2011       2014.0
# ...          ...             ...       ...     ...         ...          ...
# 361015      4003         1502400        25       M        2011       2015.0
# 361016      4003         1502400        23       M        2013       2015.0
# 361017      4003         1502400        24       M        2013       2015.0
# 361018      4003         1502400        24       F        2013       2015.0
# 361019      4003         1502400        22       M        2014       2015.0
#
# ...

# %%
my_report = sv.analyze(eng_ufpa_sem_na)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
